# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as scio

x = np.linspace(-3, 7, 100)
y = - (x - 3)**2 + 5
print(x, y)
plt.plot(x, y)
plt.show()
# Out:
# (array([-3.        , -2.8989899 , -2.7979798 , -2.6969697 , -2.5959596 ,
#        -2.49494949, -2.39393939, -2.29292929, -2.19191919, -2.09090909,
#        -1.98989899, -1.88888889, -1.78787879, -1.68686869, -1.58585859,
#        -1.48484848, -1.38383838, -1.28282828, -1.18181818, -1.08080808,
#        -0.97979798, -0.87878788, -0.77777778, -0.67676768, -0.57575758,
#        -0.47474747, -0.37373737, -0.27272727, -0.17171717, -0.07070707,
#         0.03030303,  0.13131313,  0.23232323,  0.33333333,  0.43434343,
#         0.53535354,  0.63636364,  0.73737374,  0.83838384,  0.93939394,
#         1.04040404,  1.14141414,  1.24242424,  1.34343434,  1.44444444,
#         1.54545455,  1.64646465,  1.74747475,  1.84848485,  1.94949495,
#         2.05050505,  2.15151515,  2.25252525,  2.35353535,  2.45454545,
#         2.55555556,  2.65656566,  2.75757576,  2.85858586,  2.95959596,
#         3.06060606,  3.16161616,  3.26262626,  3.36363636,  3.46464646,
#         3.56565657,  3.66666667,  3.76767677,  3.86868687,  3.96969697,
#         4.07070707,  4.17171717,  4.27272727,  4.37373737,  4.47474747,
#         4.57575758,  4.67676768,  4.77777778,  4.87878788,  4.97979798,
#         5.08080808,  5.18181818,  5.28282828,  5.38383838,  5.48484848,
#         5.58585859,  5.68686869,  5.78787879,  5.88888889,  5.98989899,
#         6.09090909,  6.19191919,  6.29292929,  6.39393939,  6.49494949,
#         6.5959596 ,  6.6969697 ,  6.7979798 ,  6.8989899 ,  7.        ]), array([-31.        , -29.79808183, -28.61656974, -27.45546373,
#        -26.3147638 , -25.19446995, -24.09458219, -23.0151005 ,
#        -21.9560249 , -20.91735537, -19.89909193, -18.90123457,
#        -17.92378329, -16.96673809, -16.03009897, -15.11386593,
#        -14.21803898, -13.3426181 , -12.48760331, -11.65299459,
#        -10.83879196, -10.04499541,  -9.27160494,  -8.51862055,
#         -7.78604224,  -7.07387001,  -6.38210387,  -5.7107438 ,
#         -5.05978982,  -4.42924191,  -3.81910009,  -3.22936435,
#         -2.66003469,  -2.11111111,  -1.58259361,  -1.0744822 ,
#         -0.58677686,  -0.1194776 ,   0.32741557,   0.75390266,
#          1.15998368,   1.54565861,   1.91092746,   2.25579023,
#          2.58024691,   2.88429752,   3.16794205,   3.43118049,
#          3.67401286,   3.89643914,   4.09845934,   4.28007346,
#          4.4412815 ,   4.58208346,   4.70247934,   4.80246914,
#          4.88205285,   4.94123049,   4.98000204,   4.99836751,
#          4.99632691,   4.97388022,   4.93102745,   4.8677686 ,
#          4.78410366,   4.68003265,   4.55555556,   4.41067238,
#          4.24538312,   4.05968779,   3.85358637,   3.62707887,
#          3.38016529,   3.11284563,   2.82511989,   2.51698806,
#          2.18845016,   1.83950617,   1.47015611,   1.08039996,
#          0.67023773,   0.23966942,  -0.21130497,  -0.68268544,
#         -1.17447199,  -1.68666463,  -2.21926334,  -2.77226814,
#         -3.34567901,  -3.93949597,  -4.55371901,  -5.18834813,
#         -5.84338333,  -6.51882461,  -7.21467197,  -7.93092542,
#         -8.66758494,  -9.42465055, -10.20212223, -11.        ]))

# %%
Plot of the graph $\lambda$

# %%
plt.plot(x, y)

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    labelbottom='off')
plt.tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelleft='off')

plt.ylabel('some numbers')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-dd59139294f9> in <module>()
#       3
#       4
# ----> 5 plt.xlabel('some numbers')
#       6 plt.show()
#
# TypeError: 'str' object is not callable
